# %%
# 1. Pedindo os dados para o usuario`npeso = float(input("Digite o seu peso (em kg): "))`naltura = float(input("Digite a sua altura (em metros): "))`n`n# 2. Calculando o IMC`nimc = peso / (altura ** 2)`n`n# 3. Exibindo o resultado formatado`nprint(f"Seu IMC e: {imc:.2f}")
