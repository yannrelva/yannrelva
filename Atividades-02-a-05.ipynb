# %%
# Atividade 2: Conversor de Temperatura (Celsius para Fahrenheit)`ncelsius = float(input("Digite a temperatura em Celsius: "))`nfahrenheit = (celsius * 9/5) + 32`nprint(f"{celsius}°C equivale a {fahrenheit:.1f}°F")

# %%
# Atividade 3: Calculadora de Desconto`npreco_original = float(input("Digite o preco do produto: R$ "))`ndesconto = float(input("Digite a porcentagem de desconto (ex: 10): "))`nvalor_desconto = preco_original * (desconto / 100)`npreco_final = preco_original - valor_desconto`nprint(f"Valor do desconto: R$ {valor_desconto:.2f}")`nprint(f"Preco final com desconto: R$ {preco_final:.2f}")

# %%
# Atividade 4: Conversor de Moedas (Real para Dolar)`nreais = float(input("Digite o valor em R$: "))`ncotacao = float(input("Digite a cotacao atual do dolar: U$ "))`ndolares = reais / cotacao`nprint(f"R$ {reais:.2f} equivalem a U$ {dolares:.2f}")

# %%
# Atividade 5: Verificador de Par ou Impar`nnumero = int(input("Digite um numero inteiro: "))`nif numero % 2 == 0:`n    print(f"O numero {numero} e PAR.")`nelse:`n    print(f"O numero {numero} e IMPAR.")
