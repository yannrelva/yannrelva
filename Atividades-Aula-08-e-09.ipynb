# %%
# Aula 08 - Exercicio: Dicionarios`naluno = {"nome": "Yann", "curso": "Engenharia da Computacao"}`nprint(aluno)

# %%
# Aula 09 - Desafio 3: Soma de Tres Argumentos`ndef soma_tres(a, b, c):`n    return a + b + c`nprint(f"Soma: {soma_tres(10, 20, 30)}")

# %%
# Aula 09 - Desafio 4: Positivo ou Negativo`ndef verificar(num):`n    return "P" if num > 0 else "N"`nprint(verificar(5))
