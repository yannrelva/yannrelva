# %%
# Aula 06 - Desafio 1: Somatoria dos Pares`nN = int(input("Digite o valor final N: "))`nsoma = 0`nfor i in range(1, N + 1):`n    if i % 2 == 0:`n        soma += i`nprint(f"A soma dos pares e: {soma}")

# %%
# Aula 06 - Desafio 2: Validacao de Nota`nwhile True:`n    nota = float(input("Digite uma nota entre 0 e 10: "))`n    if 0 <= nota <= 10:`n        print("Nota valida!")`n        break`n    print("Nota Invalida")

# %%
# Aula 07 - Exercicio 1: Operacoes com Listas`nnotas = [8.5, 7.0, 9.2, 5.5, 10.0]`nprint(f"Lista de notas: {notas}")`nprint(f"Maior nota: {max(notas)}")`nprint(f"Media: {sum(notas)/len(notas):.2f}")
